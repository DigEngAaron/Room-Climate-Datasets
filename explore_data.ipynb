# %% [markdown]
# # Humidity, Temperature, Light Sensor Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets-location_A/room_climate-location_A-measurement59.csv')

# %%
columns = ['EID', 'AbsT', 'RelT', 'NID', 'Temp', 'RelH', 'L1', 'L2', 'Occ', 'Act', 'Door', 'Win']
len(columns)
df.columns = columns
df.head()
# Out:
#    EID           AbsT  RelT  NID   Temp    RelH      L1     L2  Occ  Act  \
# 0    2  1459421355280     2    4  21.70  53.389  254.29  910.8    0    0
# 1    3  1459421355609     2    3  21.28  52.983  235.71  754.4    0    0
# 2    4  1459421356081     3    1  21.23  57.074  214.29  598.0    0    0
# 3    5  1459421359599     6    3  21.28  52.983  234.29  749.8    0    0
# 4    6  1459421359644     6    4  21.69  53.429  258.57  906.2    0    0
#
#    Door  Win
# 0     1    0
# 1     1    0
# 2     1    0
# 3     1    0
# 4     1    0

# %%
df.plot(x='EID', y='Temp')
# Out:
# <Axes: xlabel='EID'>

# %%
df.plot(x='EID', y='Occ')
# Out:
# <Axes: xlabel='EID'>

# %%
plt.subplots(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn_r', linewidths=0.5, fmt='.2f')
# Out:
# <Axes: >
